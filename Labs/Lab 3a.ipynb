# %%
from __future__ import print_function

# %%
import numpy as np

#random sampling packages in scipy.org_...outlines.random
#rand - shape of the array, shape of the distribution in uniform (each draw has the same probability)
from numpy.random import randn
import pylab as pl

# %pylab inline 
#reders plot directly on the notebook instead of a window that pops up
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#set a seed to get the same number each time
np.random.seed(999)
np.random.rand(1)
# Out:
# array([ 0.80342804])

# %%
#array of 3
np.random.rand(3)
# Out:
# array([ 0.72895073,  0.01688145,  0.3303388 ])

# %%
np.random.rand(3)
# Out:
# array([ 0.72895073,  0.01688145,  0.3303388 ])

# %%
np.random.rand(3,2)
# Out:
# array([[ 0.5275223 ,  0.11911147],
#        [ 0.63968144,  0.09092526],
#        [ 0.33222568,  0.42738095]])

# %%
#randn - a gaussian distribution
np.random.randn(3,2)
# Out:
# array([[ 0.64461671, -0.92791692],
#        [ 1.44348511, -0.52565485],
#        [-1.82416154, -0.22444073]])

# %%
uniform_array=np.random.rand(10000)
uniform_array
# Out:
# array([ 0.4816016 ,  0.30179121,  0.49396977, ...,  0.55244824,
#         0.68847103,  0.38138988])

# %%
gaussian_array=np.random.randn(10000,2)

# %%
pl.hist?

# %%
pl.hist(uniform_array)
pl.show
# Out:
# <function matplotlib.pyplot.show>

# %%
uniform_array.describe()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-41-64dcfaf23222> in <module>()
# ----> 1 uniform_array.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
#pl.hist(gaussian_array)
pl.plot(gaussian_array,".")
pl.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#the larger the sample, the truer it will fit the distribution

# %%
pl.figure(figsize =(10,10))
pl.plot(gaussian_array[0],gaussian_array[1], ".")
pl.xlim(-5,5)
pl.ylim(-5,5)
pl.show
# Out:
# <function matplotlib.pyplot.show>
