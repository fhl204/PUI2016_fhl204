# %% [markdown]
# Homework 2:
#     https://github.com/fedhere/PUI2016_fb55/tree/master/HW2_fb55
#
# Lab Resources:
#     https://github.com/fedhere/PUI2016_fb55/blob/master/Lab2_fb55/NYCweatherAPI.py
#     https://github.com/fedhere/PUI2016_fb55/blob/master/Lab2_fb55/APIreadingJson.py.ipynb
#     https://github.com/fedhere/PUI2016_fb55/blob/master/Lab2_fb55/FormattingTables.ipynb
#     https://github.com/fedhere/UInotebooks/tree/master/dataWrangling
#
# Assignment 1
#     API key and link from http://bustime.mta.info/wiki/Developers/SIRIVehicleMonitoring
#
# Script for python show_bus_locations.py MTAAPIKEY B52
#
# Notes
#     Switch kernel to python2 (urllib2 does not work in 3)

# %%
from __future__ import print_function
import json
import urllib2 
import os
import sys
import requests
import numpy as np
import pandas as pd
import pylab as pl

# %%
#urllib2.urlopen approach

#getenv not working
#apikey = os.getenv("MTAAPIKEY")

#fetch data from MTA
apikey = "b90f3cc1-5567-4fbf-9ef4-843de85a9a07" #x
mode = "Json"
units = "metric"
#MTAAPIKEY = sys.argv[1]
#BUS_LINE = sys.argv[2]
BUS_LINE = "B52"
   
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?"\
    "key="+apikey+\
    "&VehicleMonitoringDetailLevel=calls"\
    "&LineRef="+BUS_LINE

response = urllib2.urlopen(url)
MTAdata = response.read().decode("utf-8")
json.loads(MTAdata)
print (MTAdata)

''
alldataMTA = []
for l in csv:
    data = l.split(',')
    print (data)
    alldataMTA.append(data)

MTAdata2 = pd.read_json(MTAdata)
MTAdata2

#num_vehicles = 
#cur_position =
# Out:
# {"Siri":{"ServiceDelivery":{"ResponseTimestamp":"2016-09-17T11:26:17.871-04:00","VehicleMonitoringDelivery":[{"VehicleActivity":[{"MonitoredVehicleJourney":{"LineRef":"MTA NYCT_B52","DirectionRef":"0","FramedVehicleJourneyRef":{"DataFrameRef":"2016-09-17","DatedVehicleJourneyRef":"MTA NYCT_FP_D6-Saturday-066800_B52_102"},"JourneyPatternRef":"MTA_B520040","PublishedLineName":"B52","OperatorRef":"MTA NYCT","OriginRef":"MTA_307175","DestinationRef":"MTA_801117","DestinationName":"RIDGEWOOD TERM via GATES","SituationRef":[],"Monitored":true,"VehicleLocation":{"Longitude":-73.972561,"Latitude":40.685932},"Bearing":7.296946,"ProgressRate":"normalProgress","BlockRef":"MTA NYCT_FP_D6-Saturday_A_FP_22800_B52-102","VehicleRef":"MTA NYCT_6576","MonitoredCall":{"ExpectedArrivalTime":"2016-09-17T11:26:18.871-04:00","ExpectedDepartureTime":"2016-09-17T11:26:18.871-04:00","Extensions":{"Distances":{"PresentableDistance":"at stop","DistanceFromCall":0.0,"StopsFromCall":0,"CallDistanceAlongRoute":2214.45}},"StopPointRef":"MTA_307547","VisitNumber":1,"StopPointName":"GREENE AV/FULTON ST"},"OnwardCalls":{"OnwardCall":[{"ExpectedArrivalTime":"2016-09-17T11:26:17.871-04:00","ExpectedDepartureTime":"2016-09-17T11:26:17.871-04:00","Extensions":{"Distances":{"PresentableDistance":"at stop","DistanceFromCall":0.0,"StopsFromCall":0,"CallDistanceAlongRoute":2214.45}},"StopPointRef":"MTA_307547","VisitNumber":1,"StopPointName":"GREENE AV/FULTON ST"},{"ExpectedArrivalTime":"2016-09-17T11:26:48.522-04:00","ExpectedDepartureTime":"2016-09-17T11:26:48.522-04:00","Extensions":{"Distances":{"PresentableDistance":"1 stop away","DistanceFromCall":212.94,"StopsFromCall":1,"CallDistanceAlongRoute":2427.39}},"StopPointRef":"MTA_307548","VisitNumber":1,"StopPointName":"GREENE AV/ADELPHI ST"},{"ExpectedArrivalTime":"2016-09-17T11:27:46.953-04:00","ExpectedDepartureTime":"2016-09-17T11:27:46.953-04:00","Extensions":{"Distances":{"PresentableDistance":"2 stops away","DistanceFromCall":385.27,"StopsFromCall":2,"CallDistanceAlongRoute":2599.72}},"StopPointRef":"MTA_307549","VisitNumber":1,"StopPointName":"GREENE AV/VANDERBILT AV"},{"ExpectedArrivalTime":"2016-09-17T11:28:58.221-04:00","ExpectedDepartureTime":"2016-09-17T11:28:58.221-04:00","Extensions":{"Distances":{"PresentableDistance":"3 stops away","DistanceFromCall":634.57,"StopsFromCall":3,"CallDistanceAlongRoute":2849.02}},"StopPointRef":"MTA_307550","VisitNumber":1,"StopPointName":"GREENE AV/WASHINGTON AV"},{"ExpectedArrivalTime":"2016-09-17T11:30:02.821-04:00","ExpectedDepartureTime":"2016-09-17T11:30:02.821-04:00","Extensions":{"Distances":{"PresentableDistance":"0.6 miles away","DistanceFromCall":892.92,"StopsFromCall":4,"CallDistanceAlongRoute":3107.37}},"StopPointRef":"MTA_307551","VisitNumber":1,"StopPointName":"GREENE AV/GRAND AV"},{"ExpectedArrivalTime":"2016-09-17T11:31:05.768-04:00","ExpectedDepartureTime":"2016-09-17T11:31:05.768-04:00","Extensions":{"Distances":{"PresentableDistance":"0.7 miles away","DistanceFromCall":1131.73,"StopsFromCall":5,"CallDistanceAlongRoute":3346.18}},"StopPointRef":"MTA_307552","VisitNumber":1,"StopPointName":"GREENE AV/CLASSON AV"},{"ExpectedArrivalTime":"2016-09-17T11:32:10.168-04:00","ExpectedDepartureTime":"2016-09-17T11:32:10.168-04:00","Extensions":{"Distances":{"PresentableDistance":"0.8 miles away","DistanceFromCall":1364.96,"StopsFromCall":6,"CallDistanceAlongRoute":3579.41}},"StopPointRef":"MTA_307553","VisitNumber":1,"StopPointName":"FRANKLIN AV/GREENE AV"},{"ExpectedArrivalTime":"2016-09-17T11:33:09.218-04:00","ExpectedDepartureTime":"2016-09-17T11:33:09.218-04:00","Extensions":{"Distances":{"PresentableDistance":"1.0 miles away","DistanceFromCall":1612.74,"StopsFromCall":7,"CallDistanceAlongRoute":3827.19}},"StopPointRef":"MTA_307674","VisitNumber":1,"StopPointName":"GATES AV/FRANKLIN AV"},{"ExpectedArrivalTime":"2016-09-17T11:34:08.414-04:00","ExpectedDepartureTime":"2016-09-17T11:34:08.414-04:00","Extensions":{"Distances":{"PresentableDistance":"1.1 miles aw ...

# %%
'''
#Print formatted results 
print "Bus Line :" + BUS_LINE
print "Number of Active Buses :" + MTAdata.count()
For i in MTAdata:
    print "Bus " + i + " is at latitude " + lat + " and longitude " + long
'''
